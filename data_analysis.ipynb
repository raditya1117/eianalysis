# %%
import pandas as pd

# %%
data=pd.read_csv("ei_dataset.csv")

# %%
data.head()
# Out:
#              Timestamp What describes you best?  \
# 0  10/21/2020 18:14:12          Nursing student
# 1  10/28/2020 21:02:32             MBBS student
# 2  10/28/2020 21:04:10             MBBS student
# 3  10/28/2020 21:04:33             MBBS student
# 4  10/28/2020 21:04:38             MBBS student
#
#    What year of course are you in? How do you specify your gender?  \
# 0                              3.0                          Female
# 1                              2.0                          Female
# 2                              2.0                            Male
# 3                              2.0                            Male
# 4                              2.0                          Female
#
#    What's your age? What's your Grade Point Average/Percentage till now?  \
# 0                21                                                75%
# 1                20                                                  A
# ...

# %%
column_list=['What describes you best?', 'How do you specify your gender?',
       'I can recognize my emotions as I experience them.',
       'I lose my temper when I feel frustrated.',
       "People have told me that I'm a good listener.",
       'I know how to calm myself down when I feel anxious or upset.',
       'I enjoy organizing groups.',
       'I find it hard to focus on something over the long term.',
       'I find it difficult to move on when I feel frustrated or unhappy.',
       'I know my strengths and weaknesses.',
       'I avoid conflict and negotiations.',
       "I feel that I don't enjoy my work.",
       'I ask people for feedback on what I do well, and how I can improve.',
       'I set long-term goals, and review my progress regularly.',
       "I find it difficult to read other people's emotions.",
       'I struggle to build rapport with others.',
       'I use active listening skills when people speak to me.',
       '1. This face is expressing.', '2. This face is expressing.',
       '3. This face is expressing.', '4. This face is expressing.',
       '5. This face is expressing.', '6. This face is expressing.',
       '7. This face is expressing.', '8. This face is expressing.',
       '9. This face is expressing.', '10. This face is expressing.',
       '11. This face is expressing.', '12.This face is expressing.',
       '13. This face is expressing.', '14. This face is expressing.',
       '15. This face is expressing.',
       '1. You communicate with the patient in clear and polite manner.',
       "2. You critically review patient's condition and identify his/her needs.",
       '3. You anticipate the needs and follow up with patient and their family.',
       '4. You show the ability to respond to emergency situation.',
       '5. You communicate effectively with other team members while working.',
       '6. You try to solve problems as they occur.',
       '7. You feel stressed while handling emergency situations.',
       '8. You have difficulty coping at work as time passes while in duty.',
       '9. You  understand non verbal communication appropriately to convey your thoughts with others while on duty.',
       '10. You focus on patient centered communication, goals and concerns.',
       "11. You educate the patient/family about indications, actions and side effects of patient's medications every time they seek help.",
       '12. You provide patient care equally irrespective of their gender or age.',
       '13. You ask pertinent questions related to patient condition and care.',
       '14. You feel mentally exhausted after completing the clinical duty.']

# %%
data=data[column_list].dropna()

# %%
flag_dict={
    'What describes you best?':"profession",
    'How do you specify your gender?':"gender",
    'I can recognize my emotions as I experience them.':"positive_1",
    'I lose my temper when I feel frustrated.':"negative_1",
    "People have told me that I'm a good listener.":"positive_2",
    'I know how to calm myself down when I feel anxious or upset.':"positive_3",
    'I enjoy organizing groups.': "positive_4",
    'I find it hard to focus on something over the long term.':"negative_2",
    'I find it difficult to move on when I feel frustrated or unhappy.':"negative_3",
    'I know my strengths and weaknesses.':"positive_5",
    'I avoid conflict and negotiations.':"positive_6",
    "I feel that I don't enjoy my work.":"negative_4",
    'I ask people for feedback on what I do well, and how I can improve.':"positive_7",
    'I set long-term goals, and review my progress regularly.':"positive_8",
    "I find it difficult to read other people's emotions.":"negative_5",
    'I struggle to build rapport with others.':"negative_6",
    'I use active listening skills when people speak to me.':"positive_9",
    '1. This face is expressing.':'fear',
    '2. This face is expressing.':"happiness",
    '3. This face is expressing.':"anger",
    '4. This face is expressing.':"embarrassment",
    '5. This face is expressing.':"pride",
    '6. This face is expressing.':"surprise",
    '7. This face is expressing.':"contempt",
    '8. This face is expressing.':"disgust",
    '9. This face is expressing.':"flirt",
    '10. This face is expressing.':"pain",
    '11. This face is expressing.':"compassion",
    '12.This face is expressing.':"amusement",
    '13. This face is expressing.':"interest",
    '14. This face is expressing.':"sadness",
    '15. This face is expressing.':"desire",
    '1. You communicate with the patient in clear and polite manner.':"performance_p1",
    "2. You critically review patient's condition and identify his/her needs.":"performance_p2",
    '3. You anticipate the needs and follow up with patient and their family.':"performance_p3",
    '4. You show the ability to respond to emergency situation.':"performance_p4",
    '5. You communicate effectively with other team members while working.':"performance_p5",
    '6. You try to solve problems as they occur.':"performance_p6",
    '7. You feel stressed while handling emergency situations.':"performance_n1",
    '8. You have difficulty coping at work as time passes while in duty.':"performance_n2",
    '9. You  understand non verbal communication appropriately to convey your thoughts with others while on duty.':"performance_p7",
    '10. You focus on patient centered communication, goals and concerns.':"performance_p8",
    "11. You educate the patient/family about indications, actions and side effects of patient's medications every time they seek help.":"performance_p9",
    '12. You provide patient care equally irrespective of their gender or age.':"performance_p10",
    '13. You ask pertinent questions related to patient condition and care.':"performance_p11",
    '14. You feel mentally exhausted after completing the clinical duty.':"performance_n3"
    
}

# %%
flag_dict
# Out:
# {'What describes you best?': 'profession',
#  'How do you specify your gender?': 'gender',
#  'I can recognize my emotions as I experience them.': 'positive_1',
#  'I lose my temper when I feel frustrated.': 'negative_1',
#  "People have told me that I'm a good listener.": 'positive_2',
#  'I know how to calm myself down when I feel anxious or upset.': 'positive_3',
#  'I enjoy organizing groups.': 'positive_4',
#  'I find it hard to focus on something over the long term.': 'negative_2',
#  'I find it difficult to move on when I feel frustrated or unhappy.': 'negative_3',
#  'I know my strengths and weaknesses.': 'positive_5',
#  'I avoid conflict and negotiations.': 'positive_6',
#  "I feel that I don't enjoy my work.": 'negative_4',
#  'I ask people for feedback on what I do well, and how I can improve.': 'positive_7',
#  'I set long-term goals, and review my progress regularly.': 'positive_8',
#  "I find it difficult to read other people's emotions.": 'negative_5',
# ...

# %%
data=data.rename(columns=flag_dict)

# %%
data
# Out:
#          profession  gender        positive_1        negative_1  \
# 0   Nursing student  Female  Most of the time  Most of the time
# 5      MBBS student    Male        Frequently        Frequently
# 13     MBBS student  Female            Always             Never
# 14     MBBS student  Female  Most of the time            Rarely
# 15     MBBS student  Female        Frequently         Sometimes
# 16     MBBS student  Female         Sometimes  Most of the time
# 17     MBBS student    Male  Most of the time         Sometimes
# 18     MBBS student    Male            Rarely  Most of the time
# 19     MBBS student  Female  Most of the time        Frequently
# 21     MBBS student  Female  Most of the time         Sometimes
# 22     MBBS student  Female            Always        Frequently
# 29     MBBS student    Male            Always            Always
# 33     MBBS student  Female  Most of the time         Sometimes
# 36     MBBS student    Male  Most of the time            Rarely
# ...

# %%
data.columns
# Out:
# Index(['profession', 'gender', 'positive_1', 'negative_1', 'positive_2',
#        'positive_3', 'positive_4', 'negative_2', 'negative_3', 'positive_5',
#        'positive_6', 'negative_4', 'positive_7', 'positive_8', 'negative_5',
#        'negative_6', 'positive_9', 'fear', 'happiness', 'anger',
#        'embarrassment', 'pride', 'surprise', 'contempt', 'disgust', 'flirt',
#        'pain', 'compassion', 'amusement', 'interest', 'sadness', 'desire',
#        'performance_p1', 'performance_p2', 'performance_p3', 'performance_p4',
#        'performance_p5', 'performance_p6', 'performance_n1', 'performance_n2',
#        'performance_p7', 'performance_p8', 'performance_p9', 'performance_p10',
#        'performance_p11', 'performance_n3'],
#       dtype='object')

# %%
positives={"Always":5,
            "Most of the time":4,
           "Frequently":3,
            "Sometimes":2,
            "Rarely":1,
            "Never":0,
}
negatives={"Always":-5,
            "Most of the time":-4,
           "Frequently":-3,
            "Sometimes":-2,
            "Rarely":-1,
            "Never":0,
}
emotions=['fear', 'happiness', 'anger',
       'embarrassment', 'pride', 'surprise', 'contempt', 'disgust', 'flirt',
       'pain', 'compassion', 'amusement', 'interest', 'sadness', 'desire']

# %%
def get_score(column_name,data):
    if column_name=="fear":
        data["fear"]=data["fear"].apply(lambda x: 1 if x=="Fear" else 0 )
    elif column_name=="happiness":
        data["happiness"]=data["happiness"].apply(lambda x: 1 if x=="Happiness" else 0 )
    elif column_name=="anger":
        data["anger"]=data["anger"].apply(lambda x: 1 if x=="Anger" else 0 )
    elif column_name=="embarrassment":
        data["embarrassment"]=data["embarrassment"].apply(lambda x: 1 if x=="Embarrassment" else 0 )
    elif column_name=="pride":
        data["pride"]=data["pride"].apply(lambda x: 1 if x=="Pride" else 0 )
    elif column_name=="surprise":
        data["surprise"]=data["surprise"].apply(lambda x: 1 if x=="Surprise" else 0 )
    elif column_name=="contempt":
        data["contempt"]=data["contempt"].apply(lambda x: 1 if x=="Contempt" else 0 )
    elif column_name=="disgust":
        data["disgust"]=data["disgust"].apply(lambda x: 1 if x=="Disgust" else 0 )
    elif column_name=="flirt":
        data["flirt"]=data["flirt"].apply(lambda x: 1 if x=="Flirtatiousness" else 0 )
    elif column_name=="pain":
        data["pain"]=data["pain"].apply(lambda x: 1 if x=="Pain" else 0 )
    elif column_name=="compassion":
        data["compassion"]=data["compassion"].apply(lambda x: 1 if x=="Compassion" else 0 )
    elif column_name=="amusement":
        data["amusement"]=data["amusement"].apply(lambda x: 1 if x=="Amusement" else 0 )
    elif column_name=="interest":
        data["interest"]=data["interest"].apply(lambda x: 1 if x=="Interest" else 0 )
    elif column_name=="sadness":
        data["sadness"]=data["sadness"].apply(lambda x: 1 if x=="Sadness" else 0 )
    elif column_name=="desire":
        data["desire"]=data["desire"].apply(lambda x: 1 if x=="Desire" else 0 )
    return data

# %%
for column_name in emotions:
    data=get_score(column_name,data)

# %%
data[emotions]
# Out:
#     fear  happiness  anger  embarrassment  pride  surprise  contempt  disgust  \
# 0      0          0      0              0      1         1         1        1
# 5      0          1      1              0      1         1         0        1
# 13     1          0      1              0      1         1         1        1
# 14     1          0      1              0      1         1         1        0
# 15     0          0      1              1      1         1         1        1
# 16     0          0      0              0      1         1         0        0
# 17     0          0      0              0      1         1         1        1
# 18     0          1      1              0      1         1         0        0
# 19     0          1      1              1      1         1         1        1
# 21     0          1      0              0      1         1         1        0
# 22     0          1      1              0      1         1         0        1
# ...

# %%
positive_columns=['profession', 'gender', 'positive_1', 'positive_2',
       'positive_3', 'positive_4', 'positive_5',
       'positive_6', 'positive_7', 'positive_8', 'positive_9',
       'performance_p1', 'performance_p2', 'performance_p3', 'performance_p4',
       'performance_p5', 'performance_p6',
       'performance_p7', 'performance_p8', 'performance_p9', 'performance_p10',
       'performance_p11']

# %%
negative_columns=['negative_1','negative_2', 'negative_3','negative_4', 'negative_5',
       'negative_6', 'performance_n1', 'performance_n2', 'performance_n3']

# %%
for col_name in positive_columns:
    data[col_name]=data[col_name].replace(positives)
# Out:
# /tmp/ipykernel_19494/104607347.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[col_name]=data[col_name].replace(positives)

# %%
for col_name in negative_columns:
    data[col_name]=data[col_name].replace(negatives)
# Out:
# /tmp/ipykernel_19494/2406780228.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[col_name]=data[col_name].replace(negatives)

# %%
data
# Out:
#          profession  gender  positive_1  negative_1  positive_2  positive_3  \
# 0   Nursing student  Female           4          -4           2           2
# 5      MBBS student    Male           3          -3           4           4
# 13     MBBS student  Female           5           0           4           5
# 14     MBBS student  Female           4          -1           4           4
# 15     MBBS student  Female           3          -2           3           5
# 16     MBBS student  Female           2          -4           5           2
# 17     MBBS student    Male           4          -2           5           5
# 18     MBBS student    Male           1          -4           2           0
# 19     MBBS student  Female           4          -3           4           4
# 21     MBBS student  Female           4          -2           4           4
# 22     MBBS student  Female           5          -3           0           4
# ...
